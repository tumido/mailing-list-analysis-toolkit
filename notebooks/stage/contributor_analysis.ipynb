# %% [markdown]
# # Contributor Analysis
#
# This notebook ingests the preprocessed data from `../interim/metadata` downloaded by `download_datasets.ipynb` and quantifies the activity of individual contributors to the mailing list, including frequency of initial senders to a thread, and frequency of all replies to existing threads in the mailing list. Both of these analyses are performed on monthly intervals.
#
# Finally, the analyses are merged and saved as a single csv file that is pushed to remote storage for visualization with Superset.

# %%
import pandas as pd
import os
import datetime
import re
from pathlib import Path
from dotenv import load_dotenv

load_dotenv("../../.env")

import sys

sys.path.append("../..")
from src import utils

# %%
BASE_PATH = os.getenv("LOCAL_DATA_PATH", "../../data/")

# %%
df = utils.load_dataset(f"{BASE_PATH}interim/metadata/")

# %%
df.head()
# Out:
#                                           Message-ID  \
# 0                     <1519862707.18745.0@posteo.de>
# 1  <b88b4d3b-b8f7-2ea6-ec41-ab572b831717@dustymab...
# 2  <45117c81-43ff-656d-85c3-3cf003bd0d14@fedorapr...
# 3  <CAA55FSN-R4oV0os0LihZQTp8aa0NkR9jQPh44subK2+9...
# 4                    <p77nrn$t3b$1@blaine.gmane.org>
#
#                               Date  \
# 0  Wed, 28 Feb 2018 18:05:07 -0600
# 1  Wed, 28 Feb 2018 19:43:15 -0500
# 2  Wed, 28 Feb 2018 20:49:25 -0500
# 3  Wed, 28 Feb 2018 21:11:19 -0500
# 4  Thu, 01 Mar 2018 03:19:34 +0100
#
#                                              From  \
# 0                         mcatanzaro at gnome.org
# 1             Dusty Mabe <dusty at dustymabe.com>
# 2  Randy Barlow <bowlofeggs at fedoraproject.org>
# 3        Orcan Ogetbil <oget.fedora at gmail.com>
# 4        Kevin Kofler <kevin.kofler at chello.at>
#
#                                  To  \
# 0  devel at lists.fedoraproject.org
# 1  devel at lists.fedoraproject.org
# 2  devel at lists.fedoraproject.org
# 3  devel at lists.fedoraproject.org
# 4  devel at lists.fedoraproject.org
#
#                                              Subject  \
# 0                   Re: Test gating enabled in Bodhi
# 1  Re: Unannounced soname bump (Rawhide): qpdf (l...
# 2                   Re: Test gating enabled in Bodhi
# 3  Re: <DKIM> Re: <DKIM> Re: <DKIM> Re: [ACTION N...
# 4  Frequently broken Rawhide/Branched composes (w...
#
#                                          In-Reply-To
# 0  CAM86y2s-RnNmKDpQGQK12Y1VHGx-142AzFOgzc4oDqy7w...
# 1                  20180228183836.GB17774@redhat.com
# 2                       1519862707.18745.0@posteo.de
# 3       0c2eeac1ff3aad727094f24c1c704d22@laposte.net
# 4  CAB-QmhQrFTSLwt0dvqgpNkbKa7zVum9KnpRVAa33o4OMA...

# %% [markdown]
# ##  Minor preprocessing
#
# Here we need to do some minor cleaning to the "subject", "text" and "date" fields to correctly rearrange the dataframe so that all messages from the same thread are grouped together.

# %%
# get all participants regradles of response
def match_threads(subject):
    return re.sub(r"^{0}".format(re.escape("Re: ")), "", subject)


# remove trailing emials
def remove_email(text):
    return re.sub(r" <.*", "", text)


# convert date string to datetime object
def parse_date(date):
    return pd.to_datetime(date)


def asked_or_responded(in_reply_to):
    return int(pd.isna(in_reply_to))

# %%
# apply our transformations

df["Subject"] = df["Subject"].apply(match_threads)
df["From"] = df["From"].apply(remove_email)
df["Date"] = df["Date"].apply(parse_date)
df["Chunk"] = df["Date"].apply(lambda x: datetime.date(x.year, x.month, 1))
df["Asked"] = df["In-Reply-To"].apply(asked_or_responded)
df = df.sort_values(by="Date")
df.reset_index(inplace=True, drop=True)
df.head()
# Out:
#                                           Message-ID  \
# 0  <57d76b65c8c848f7e1b83e56ff8f094ce3855479.came...
# 1         <20180101172438.GA2871@flame.pingoured.fr>
# 2  <20180101220004.0632660A400B@fedocal02.phx2.fe...
# 3  <20180101220004.0E97560A400C@fedocal02.phx2.fe...
# 4  <20180101221314.GA52721@rawhide-composer.phx2....
#
#                         Date                   From  \
# 0  2017-12-31 18:42:21-08:00        Adam Williamson
# 1  2018-01-01 18:24:38+01:00     Pierre-Yves Chibon
# 2  2018-01-01 22:00:04+00:00     nils at redhat.com
# 3  2018-01-01 22:00:04+00:00     nils at redhat.com
# 4  2018-01-01 22:13:15+00:00  Fedora Rawhide Report
#
#                                  To  \
# 0  devel at lists.fedoraproject.org
# 1  devel at lists.fedoraproject.org
# 2  devel at lists.fedoraproject.org
# 3  devel at lists.fedoraproject.org
# 4  devel at lists.fedoraproject.org
#
#                                              Subject  \
# 0  Anything we can do to temporarily halt new bug...
# 1  [Bug 1529276] New: findbugs-contrib-7.2.0.sb i...
# 2  [Fedocal] Reminder meeting : Modularity Office...
# 3  [Fedocal] Reminder meeting : Modularity Office...
# 4  Fedora rawhide compose report: 20180101.n.0 ch...
#
#                          In-Reply-To       Chunk  Asked
# 0  20171231163359.GL17340@redhat.com  2017-12-01      0
# 1     20171231200124.15b636ef@noname  2018-01-01      0
# 2                                NaN  2018-01-01      1
# 3                                NaN  2018-01-01      1
# 4                                NaN  2018-01-01      1

# %% [markdown]
# ## Quantify contributor activity

# %%
# Quantify askers over the entire dataset
askers = (
    df[df["Asked"] is True]
    .groupby("From")
    .count()
    .sort_values("Subject", ascending=False)
)
askers.head(15)
# Out:
#                                                     Message-ID  Date    To  \
# From
# Fedora compose checker                                    1781  1781  1781
# Fedora Rawhide Report                                      697   697   697
# Ben Cotton                                                 397   397   397
# =?utf-8?q?Miro_Hron=C4=8Dok_=3Cmhroncok_at_redh...         311   311   311
# Adam Williamson                                            267   267   267
# Fedora Branched Report                                     252   252   252
# rawhide at fedoraproject.org                               182   182   182
# Fabio Valentini                                            153   153   153
# Richard Shaw                                               145   145   145
# Jan Kurik                                                  132   132   132
# Richard W.M. Jones                                         111   111   111
# Jerry James                                                105   105   105
# James Antill                                                99    99    99
# Ankur Sinha                                                 98    98    98
# nils at redhat.com                                          93    93    93
#
#                                                     Subject  In-Reply-To  \
# From
# Fedora compose checker                                 1781            0
# Fedora Rawhide Report                                   697            0
# Ben Cotton                                              397            0
# =?utf-8?q?Miro_Hron=C4=8Dok_=3Cmhroncok_at_redh...      311            0
# Adam Williamson                                         267            0
# Fedora Branched Report                                  252            0
# rawhide at fedoraproject.org                            182            0
# Fabio Valentini                                         153            0
# Richard Shaw                                            145            0
# Jan Kurik                                               132            0
# Richard W.M. Jones                                      111            0
# Jerry James                                             105            0
# James Antill                                             99            0
# Ankur Sinha                                              98            0
# nils at redhat.com                                       93            0
#
#                                                     Chunk  Asked
# From
# Fedora compose checker                               1781   1781
# Fedora Rawhide Report                                 697    697
# Ben Cotton                                            397    397
# =?utf-8?q?Miro_Hron=C4=8Dok_=3Cmhroncok_at_redh...    311    311
# Adam Williamson                                       267    267
# Fedora Branched Report                                252    252
# rawhide at fedoraproject.org                          182    182
# Fabio Valentini                                       153    153
# Richard Shaw                                          145    145
# Jan Kurik                                             132    132
# Richard W.M. Jones                                    111    111
# Jerry James                                           105    105
# James Antill                                           99     99
# Ankur Sinha                                            98     98
# nils at redhat.com                                     93     93

# %%
# Quantify responders over the entire dataset

responders = (
    df[df["Asked"] is False]
    .groupby("From")
    .count()
    .sort_values("Subject", ascending=False)
)
responders.head(15)
# Out:
#                                                     Message-ID  Date    To  \
# From
# =?utf-8?q?Miro_Hron=C4=8Dok_=3Cmhroncok_at_redh...        1636  1636  1636
# Neal Gompa                                                 973   973   973
# Adam Williamson                                            888   888   888
# =?utf-8?q?Zbigniew_J=C4=99drzejewski-Szmek_=3Cz...         887   887   887
# Kevin Fenzi                                                853   853   853
# Kevin Kofler                                               740   740   740
# Chris Murphy                                               682   682   682
# Fabio Valentini                                            664   664   664
# =?utf-8?q?V=C3=ADt_Ondruch_=3Cvondruch_at_redha...         580   580   580
# Florian Weimer                                             574   574   574
# Nicolas Mailhot                                            504   504   504
# Matthew Miller                                             502   502   502
# John M. Harris Jr                                          495   495   495
# Stephen John Smoogen                                       444   444   444
# Richard W.M. Jones                                         397   397   397
#
#                                                     Subject  In-Reply-To  \
# From
# =?utf-8?q?Miro_Hron=C4=8Dok_=3Cmhroncok_at_redh...     1636         1636
# Neal Gompa                                              973          973
# Adam Williamson                                         888          888
# =?utf-8?q?Zbigniew_J=C4=99drzejewski-Szmek_=3Cz...      887          887
# Kevin Fenzi                                             853          853
# Kevin Kofler                                            740          740
# Chris Murphy                                            682          682
# Fabio Valentini                                         664          664
# =?utf-8?q?V=C3=ADt_Ondruch_=3Cvondruch_at_redha...      580          580
# Florian Weimer                                          574          574
# Nicolas Mailhot                                         504          504
# Matthew Miller                                          502          502
# John M. Harris Jr                                       495          495
# Stephen John Smoogen                                    444          444
# Richard W.M. Jones                                      397          397
#
#                                                     Chunk  Asked
# From
# =?utf-8?q?Miro_Hron=C4=8Dok_=3Cmhroncok_at_redh...   1636   1636
# Neal Gompa                                            973    973
# Adam Williamson                                       888    888
# =?utf-8?q?Zbigniew_J=C4=99drzejewski-Szmek_=3Cz...    887    887
# Kevin Fenzi                                           853    853
# Kevin Kofler                                          740    740
# Chris Murphy                                          682    682
# Fabio Valentini                                       664    664
# =?utf-8?q?V=C3=ADt_Ondruch_=3Cvondruch_at_redha...    580    580
# Florian Weimer                                        574    574
# Nicolas Mailhot                                       504    504
# Matthew Miller                                        502    502
# John M. Harris Jr                                     495    495
# Stephen John Smoogen                                  444    444
# Richard W.M. Jones                                    397    397

# %%
# Generate results for each contributor for each month

contributors = df["From"].unique()

db = {}
for c in contributors:
    participated = df[df["From"] == c].groupby("Chunk")["Asked"].count()
    started = df[df["From"] == c].groupby("Chunk")["Asked"].sum()
    responded = participated - started
    name = pd.Series([c] * len(responded))
    db[c] = pd.concat([started, responded], axis=1)
    db[c]["name"] = c
    db[c].columns = ["asked", "responded", "name"]

# %%
contributor_data_set = pd.DataFrame(columns=["asked", "responded", "name"])
for c in db.keys():
    contributor_data_set = pd.concat([contributor_data_set, db[c]])

# %%
contributor_data_set.shape
# Out:
# (7819, 3)

# %%
contributor_data_set = contributor_data_set.reset_index().set_index("name")

# %%
contributor_data_set.rename(columns={"index": "date"}, inplace=True)

# %%
contributor_data_set
# Out:
#                          date asked responded
# name
# Adam Williamson    2017-12-01     0         1
# Adam Williamson    2018-01-01    12        49
# Adam Williamson    2018-02-01     8        25
# Adam Williamson    2018-03-01    16        61
# Adam Williamson    2018-04-01     9        23
# ...                       ...   ...       ...
# Dylan M Taylor     2020-11-01     0         4
# Wim Taymans        2020-11-01     0         2
# Ondrej Pohorelsky  2020-11-01     1         1
# Ed Neville         2020-11-01     1         0
# Ondra Kalousek     2020-11-01     1         0
#
# [7819 rows x 3 columns]

# %% [markdown]
# ## Upload results to S3

# %%
new_files = (
    (contributor_data_set, f"{BASE_PATH}/processed/contributors.csv"),
)

# %%
Path(f"{BASE_PATH}/processed").mkdir(parents=True, exist_ok=True)

# %%
contributor_data_set.to_csv(new_files[0][1], header=False)

# %%
if os.getenv("RUN_IN_AUTOMATION"):
    utils.upload_files(
        (f, f"processed/{Path(f).stem}/contributors.csv") for _, f in new_files
    )
